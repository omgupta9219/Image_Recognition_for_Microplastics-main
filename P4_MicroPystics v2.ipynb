# %%
# 📌 Cell 1: Importing Dependencies
import matplotlib.pyplot as plt
import numpy as np
import os
import cv2

# YOLO import
from ultralytics import YOLO
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
# Mounting Google Drive.  Don't have to run again if it has already been mounted.
#drive.mount('/content/drive')

# Providing the Paths to the Training, Validation, and Testing data
training_path = r"C:\Users\lenovo\Desktop\Image_Recognition_for_Microplastics-main\Resources\1_Training"
validation_path =r"C:\Users\lenovo\Desktop\Image_Recognition_for_Microplastics-main\Resources\2_Validation"
testing_path = r"C:\Users\lenovo\Desktop\Image_Recognition_for_Microplastics-main\Resources\3_Testing"

# Resizing the jpgs to 128x128 to reduce processing needs and to provide uniform images
def resize_images(image):
    resized_image = resize(image.squeeze(), (128, 128))
    return np.expand_dims(resized_image, axis=-1)

# Loading the JPGs as B&W to save memory
def rgb_to_gray(image):
    return rgb2gray(image)

# Setting random seeds for Numpy & TensorFlow for reproducibility
np.random.seed(14)
tf.random.set_seed(14)

# All jpgs should be the same size (128,128), however, rescaling in anticipation of Neural Networking modeling later in the process.
# Allowing for some variation in image orientation.
datagen = ImageDataGenerator(
    rescale=1./255,
    validation_split=0.2,
    preprocessing_function=lambda x: resize(x.squeeze(), (128, 128)),
    featurewise_center=True,
    featurewise_std_normalization=True,
    rotation_range=180,
    width_shift_range=0.15,
    height_shift_range=0.15,
    horizontal_flip=True,
    fill_mode='nearest',
)

# Fitting the ImageDataGenerator onto the Training data
datagen.fit(np.zeros((1, 128, 128, 3)))

# Defining Training and Validation sets
train_generator = datagen.flow_from_directory(
    training_path,
    target_size=(128, 128),
    batch_size=924,
    class_mode='binary',
    subset='training'
)

validation_generator = datagen.flow_from_directory(
    validation_path,
    target_size=(128, 128),
    batch_size=230,
    class_mode='binary',
    subset='validation'
)
# Out:
# Found 924 images belonging to 2 classes.
# Found 40 images belonging to 2 classes.

# %%
# Check to see what it is we loaded into the Training Set
# Loading the first batch from train_generator
batch = next(train_generator)

# Extracting the images and labels from the batch
images, labels = batch

# Updating labels for better readability
updated_labels = ["Clean" if label == 0 else "Plastics" for label in labels]

# Displaying the first few images along with their labels
num_images_to_display = 5
for i in range(num_images_to_display):
    plt.subplot(1, num_images_to_display, i + 1)
    plt.imshow(images[i][:, :, 0], cmap='gray')
    plt.title(f"{updated_labels[i]}")
    plt.axis('off')

plt.show()

# %%
# Double checking the shape of the output from the resizing
# Even though images are Greyscale, we want to make sure that the color channels are 3, so they are compatable with MobileNetV2.
sample_batch = next(train_generator)
sample_image = sample_batch[0][0]
print("Shape after resize_images:", sample_image.shape)
# Out:
# Shape after resize_images: (128, 128, 3)

# %%
# Building the Image Classification Model, using Convolutional Neural Network, via MobileNetV2
base_model = MobileNetV2(weights='imagenet', include_top=False, input_shape=(128, 128, 3))

# Freezing the convolutional base
base_model.trainable = False

# Modeling with classification head on top of MobileNetV2
model = Sequential([
    base_model,
    layers.GlobalAveragePooling2D(),
    layers.Dense(256, activation='relu'),
    layers.Dropout(0.4),
    layers.Dense(128, activation='relu'),
    layers.Dropout(0.3),
    layers.Dense(64, activation='leaky_relu'),
    layers.Dropout(0.2),
    layers.Dense(1, activation='sigmoid')
])

# Compiling the model
model.compile(optimizer=Adam(), loss='binary_crossentropy', metrics=['accuracy'])

# %%
# Training the Model
epochs = 50

history = model.fit(train_generator,
                    epochs=epochs,
                    validation_data=validation_generator)

# Generating Evaluation from the Training & Validation Sets
train_loss, train_accuracy = model.evaluate(train_generator)
valid_loss, valid_accuracy = model.evaluate(validation_generator)

# Displaying accuracy & loss.
print(f'Training Accuracy: {train_accuracy}')
print(f'Training Loss: {train_loss}')
print(f'----------------------------------------')
print(f'Validation Accuracy: {valid_accuracy}')
print(f'Validation Loss: {valid_loss}')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 4
#       1 # Training the Model
#       2 epochs = 50
# ----> 4 history = model.fit(train_generator,
#       5                     epochs=epochs,
#       6                     validation_data=validation_generator)
#       8 # Generating Evaluation from the Training & Validation Sets
#       9 train_loss, train_accuracy = model.evaluate(train_generator)
#
# NameError: name 'model' is not defined

# %%
# Evaluating the model on the testing set
testing_generator = datagen.flow_from_directory(
    testing_path,
    target_size=(128, 128),
    batch_size=200,
    class_mode='binary',
    shuffle=False
)

# Generating Evaluation from the testing set
test_loss, test_accuracy = model.evaluate(testing_generator)

# Displaying accuracy & loss
print(f'Testing Accuracy: {test_accuracy}')
print(f'Testing Loss: {test_loss}')
# Out:
# Found 200 images belonging to 2 classes.
# c:\Users\lenovo\AppData\Local\Programs\Python\Python313\Lib\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.6950 - loss: 0.5756
# Testing Accuracy: 0.6949999928474426
# Testing Loss: 0.5756493210792542

# %%
# Generating predictions on the testing set
predictions = model.predict(testing_generator)

# Converting predictions to binary values (0 or 1)
binary_predictions = (predictions > 0.5).astype(int)

# Getting true labels from the generator
true_labels = testing_generator.classes

# Displaying confusion matrix
conf_matrix = confusion_matrix(true_labels, binary_predictions)
print("Confusion Matrix:")
print(conf_matrix)

# Displaying classification report
classification_rep = classification_report(true_labels, binary_predictions)
print("Classification Report:")
print(classification_rep)

# Displaying accuracy & loss
print(f'Testing Accuracy: {test_accuracy}')
print(f'Testing Loss: {test_loss}')
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step
# Confusion Matrix:
# [[61 39]
#  [26 74]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.70      0.61      0.65       100
#            1       0.65      0.74      0.69       100
#
#     accuracy                           0.68       200
#    macro avg       0.68      0.68      0.67       200
# weighted avg       0.68      0.68      0.67       200
#
# Testing Accuracy: 0.6800000071525574
# Testing Loss: 0.5767329931259155

# %%
import os
from tensorflow.keras.preprocessing import image
import numpy as np

# Define the testing path and plastic subdirectory
testing_path2 = '/content/drive/MyDrive/P4_MicroPystics/Resources/3_Testing/2_Macroplastics'
#plastic = "2_Macroplastics"

val_path = os.path.join(testing_path2)
val_pics = os.listdir(testing_path2)

# Assuming val_pics is a list of image paths
image_filename = val_pics[11]
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[37], line 10
#       7 #plastic = "2_Macroplastics"
#       9 val_path = os.path.join(testing_path2)
# ---> 10 val_pics = os.listdir(testing_path2)
#      12 # Assuming val_pics is a list of image paths
#      13 image_filename = val_pics[11]
#
# FileNotFoundError: [WinError 3] The system cannot find the path specified: '/content/drive/MyDrive/P4_MicroPystics/Resources/3_Testing/2_Macroplastics'

# %%
image_filename
image_path = os.path.join(testing_path2, image_filename)

# %%
# Load and preprocess the single image
img = image.load_img(image_path, target_size=(128, 128))  # Adjust the target_size as needed
img_array = image.img_to_array(img)
img_array = np.expand_dims(img_array, axis=0)
#img_array = preprocess_input(img_array)  # Assuming you have a preprocess_input function

# Generate predictions for the single image
single_image_predictions = model.predict(img_array)

# Convert predictions to binary values (0 or 1)
single_image_binary_prediction = (single_image_predictions > 0.5).astype(int)

# Print the results
print("Raw Predictions:", single_image_predictions)
print("Binary Prediction:", single_image_binary_prediction)
# Out:
# 1/1 [==============================] - 2s 2s/step
# Raw Predictions: [[0.98382413]]
# Binary Prediction: [[1]]

# %%
# Saving as H5 file for Interactive Model
model.save_weights('MicroPystics.weights.h5')

# %%
model.save("modelv2/saved_model")

# !zip -r /content/modelv2.zip /content/modelv2
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 model.save("modelv2/saved_model")
#       3 get_ipython().system('zip -r /content/modelv2.zip /content/modelv2')
#
# File c:\Users\lenovo\AppData\Local\Programs\Python\Python313\Lib\site-packages\keras\src\utils\traceback_utils.py:122, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#     120     # To get the full stack trace, call:
#     121     # `keras.config.disable_traceback_filtering()`
# --> 122     raise e.with_traceback(filtered_tb) from None
#     123 finally:
#     124     del filtered_tb
#
# File c:\Users\lenovo\AppData\Local\Programs\Python\Python313\Lib\site-packages\keras\src\saving\saving_api.py:114, in save_model(model, filepath, overwrite, zipped, **kwargs)
#     110 if str(filepath).endswith((".h5", ".hdf5")):
#     111     return legacy_h5_format.save_model_to_hdf5(
#     112         model, filepath, overwrite, include_optimizer
#     113     )
# --> 114 raise ValueError(
#     115     "Invalid filepath extension for saving. "
#     116     "Please add either a `.keras` extension for the native Keras "
#     117     f"format (recommended) or a `.h5` extension. "
#     118     "Use `model.export(filepath)` if you want to export a SavedModel "
#     119     "for use with TFLite/TFServing/etc. "
#     120     f"Received: filepath={filepath}."
#     121 )
#
# ValueError: Invalid filepath extension for saving. Please add either a `.keras` extension for the native Keras format (recommended) or a `.h5` extension. Use `model.export(filepath)` if you want to export a SavedModel for use with TFLite/TFServing/etc. Received: filepath=modelv2/saved_model.

# %%
# # Testing alternative activation functions to find best candidates

# # Creating activation list
# activation_functions = ['leaky_relu', 'elu', 'tanh', 'selu', 'sigmoid', 'relu']

# # Creating a dictionary to hold the activation function accuracy results
# results = {}

# # For-Looping the activation functions through the model
# for activation in activation_functions:
#     print(f"Training model with activation: {activation}")

#     model = Sequential([
#         base_model,
#         GlobalAveragePooling2D(),
#         Dense(128, activation='relu'),
#         Dropout(0.5),
#         Dense(64, activation=activation),
#         Dropout(0.3),
#         Dense(1, activation='sigmoid')
#     ])

#     model.compile(optimizer=Adam(), loss='binary_crossentropy', metrics=['accuracy'])

#     # Training the model
#     history = model.fit(train_generator, epochs=15, validation_data=validation_generator)

#     # Pulling the results
#     results[activation] = history.history['val_accuracy']

# # Plotting the results
# plt.figure(figsize=(10, 6))
# Out:
# Training model with activation: leaky_relu
# Epoch 1/15
# 1/1 [==============================] - 21s 21s/step - loss: 1.5362 - accuracy: 0.2873 - val_loss: 0.5787 - val_accuracy: 0.8000
# Epoch 2/15
# 1/1 [==============================] - 15s 15s/step - loss: 0.7608 - accuracy: 0.5680 - val_loss: 0.5319 - val_accuracy: 0.8000
# Epoch 3/15
# 1/1 [==============================] - 15s 15s/step - loss: 0.6673 - accuracy: 0.7041 - val_loss: 0.5356 - val_accuracy: 0.8000
# Epoch 4/15
# 1/1 [==============================] - 15s 15s/step - loss: 0.7079 - accuracy: 0.7279 - val_loss: 0.5152 - val_accuracy: 0.8000
# Epoch 5/15
# 1/1 [==============================] - 16s 16s/step - loss: 0.7269 - accuracy: 0.7149 - val_loss: 0.4978 - val_accuracy: 0.8000
# Epoch 6/15
# 1/1 [==============================] - 16s 16s/step - loss: 0.6831 - accuracy: 0.7192 - val_loss: 0.4997 - val_accuracy: 0.8000
# Epoch 7/15
# 1/1 [==============================] - 15s 15s/step - loss: 0.6691 - accuracy: 0.7063 - val_loss: 0.4784 - val_accuracy: 0.8000
# Epoch 8/15
# 1/1 [==============================] - 17s 17s/step - loss: 0.6346 - accuracy: 0.7171 - val_loss: 0.4784 - val_accuracy: 0.8000
# Epoch 9/15
# 1/1 [==============================] - 15s 15s/step - loss: 0.6145 - accuracy: 0.6933 - val_loss: 0.4638 - val_accuracy: 0.8000
# Epoch 10/15
# 1/1 [==============================] - 15s 15s/step - loss: 0.6334 - accuracy: 0.6587 - val_loss: 0.4951 - val_accuracy: 0.8000
# Epoch 11/15
# 1/1 [==============================] - 15s 15s/step - loss: 0.6223 - accuracy: 0.6587 - val_loss: 0.4641 - val_accuracy: 0.8000
# Epoch 12/15
# 1/1 [==============================] - 15s 15s/step - loss: 0.6009 - accuracy: 0.6739 - val_loss: 0.4897 - val_accuracy: 0.8000
# Epoch 13/15
# 1/1 [==============================] - 15s 15s/step - loss: 0.6097 - accuracy: 0.6674 - val_loss: 0.4557 - val_accuracy: 0.8000
# Epoch 14/15
# 1/1 [==============================] - 14s 14s/step - loss: 0.5977 - accuracy: 0.6760 - val_loss: 0.4638 - val_accuracy: 0.8000
# Epoch 15/15
# 1/1 [==============================] - 15s 15s/step - loss: 0.5374 - accuracy: 0.7322 - val_loss: 0.4439 - val_accuracy: 0.8000
# Training model with activation: elu
# Epoch 1/15
# 1/1 [==============================] - 21s 21s/step - loss: 0.9422 - accuracy: 0.4298 - val_loss: 0.5687 - val_accuracy: 0.8000
# Epoch 2/15
# 1/1 [==============================] - 17s 17s/step - loss: 0.7491 - accuracy: 0.7063 - val_loss: 0.5989 - val_accuracy: 0.8000
# Epoch 3/15
# 1/1 [==============================] - 16s 16s/step - loss: 0.8089 - accuracy: 0.7192 - val_loss: 0.5418 - val_accuracy: 0.8000
# Epoch 4/15
# 1/1 [==============================] - 15s 15s/step - loss: 0.7548 - accuracy: 0.7235 - val_loss: 0.4710 - val_accuracy: 0.8000
# Epoch 5/15
# 1/1 [==============================] - 16s 16s/step - loss: 0.6306 - accuracy: 0.7127 - val_loss: 0.5058 - val_accuracy: 0.8000
# Epoch 6/15
# 1/1 [==============================] - 15s 15s/step - loss: 0.6021 - accuracy: 0.6933 - val_loss: 0.5306 - val_accuracy: 0.8500
# Epoch 7/15
# 1/1 [==============================] - 15s 15s/step - loss: 0.6374 - accuracy: 0.6609 - val_loss: 0.4806 - val_accuracy: 0.9000
# Epoch 8/15
# 1/1 [==============================] - 15s 15s/step - loss: 0.5708 - accuracy: 0.6955 - val_loss: 0.4722 - val_accuracy: 0.9000
# Epoch 9/15
# 1/1 [==============================] - 14s 14s/step - loss: 0.5134 - accuracy: 0.7797 - val_loss: 0.4181 - val_accuracy: 0.8000
# Epoch 10/15
# 1/1 [==============================] - 16s 16s/step - loss: 0.5131 - accuracy: 0.7451 - val_loss: 0.4000 - val_accuracy: 0.8000
# Epoch 11/15
# 1/1 [==============================] - 16s 16s/step - loss: 0.5138 - accuracy: 0.7387 - val_loss: 0.3660 - val_accuracy: 0.8000
# Epoch 12/15
# 1/1 [==============================] - 15s 15s/step - loss: 0.5321 - accuracy: 0.7495 - val_loss: 0.3532 - val_accuracy: 0.8000
# Epoch 13/15
# 1/1 [==============================] - 15s 15s/step - loss: 0.5352 - accuracy: 0.7473 - val_loss: 0.3311 - val_accuracy: 0.9000
# Epoch 14/15
# 1/1 [==============================] - 14s 14s/step - loss: 0.4948 - accuracy: 0.7689 - val_loss: 0.3844 - val_accuracy: 0.8500
# Epoch 15/15
# 1/1 [==============================] - 15s 15s/step - loss: 0.4741 - accuracy: 0.7883 - val_loss: 0.3063 - val_accuracy: 0.9500
# Training model with activation: tanh
# Epoch 1/15
# 1/1 [==============================] - 20s 20s/step - loss: 0.9970 - accuracy: 0.4168 - val_loss: 0.4752 - val_accuracy: 0.8000
# Epoch 2/15
# 1/1 [==============================] - 15s 15s/step - loss: 0.6237 - accuracy: 0.7106 - val_loss: 0.5438 - val_accuracy: 0.8000
# Epoch 3/15
# 1/1 [==============================] - 16s 16s/step - loss: 0.6879 - accuracy: 0.7192 - val_loss: 0.5603 - val_accuracy: 0.8000
# Epoch 4/15
# 1/1 [==============================] - 15s 15s/step - loss: 0.6812 - accuracy: 0.7322 - val_loss: 0.4625 - val_accuracy: 0.8000
# Epoch 5/15
# 1/1 [==============================] - 15s 15s/step - loss: 0.6818 - accuracy: 0.7127 - val_loss: 0.4482 - val_accuracy: 0.8000
# Epoch 6/15
# 1/1 [==============================] - 23s 23s/step - loss: 0.6297 - accuracy: 0.7279 - val_loss: 0.3513 - val_accuracy: 0.8000
# Epoch 7/15
# 1/1 [==============================] - 15s 15s/step - loss: 0.6183 - accuracy: 0.7041 - val_loss: 0.3903 - val_accuracy: 0.8000
# Epoch 8/15
# 1/1 [==============================] - 15s 15s/step - loss: 0.5917 - accuracy: 0.7041 - val_loss: 0.4381 - val_accuracy: 0.8000
# Epoch 9/15
# 1/1 [==============================] - 15s 15s/step - loss: 0.6141 - accuracy: 0.6803 - val_loss: 0.4588 - val_accuracy: 0.8500
# Epoch 10/15
# 1/1 [==============================] - 18s 18s/step - loss: 0.6030 - accuracy: 0.6847 - val_loss: 0.3537 - val_accuracy: 0.9000
# Epoch 11/15
# 1/1 [==============================] - 16s 16s/step - loss: 0.6007 - accuracy: 0.6803 - val_loss: 0.3179 - val_accuracy: 0.8500
# Epoch 12/15
# 1/1 [==============================] - 15s 15s/step - loss: 0.5533 - accuracy: 0.7214 - val_loss: 0.3408 - val_accuracy: 0.8500
# Epoch 13/15
# 1/1 [==============================] - 15s 15s/step - loss: 0.5846 - accuracy: 0.7279 - val_loss: 0.3003 - val_accuracy: 0.8500
# Epoch 14/15
# 1/1 [==============================] - 15s 15s/step - loss: 0.5056 - accuracy: 0.7927 - val_loss: 0.2739 - val_accuracy: 0.8500
# Epoch 15/15
# 1/1 [==============================] - 15s 15s/step - loss: 0.5674 - accuracy: 0.7430 - val_loss: 0.3699 - val_accuracy: 0.8000
# Training model with activation: selu
# Epoch 1/15
# 1/1 [==============================] - 20s 20s/step - loss: 0.9477 - accuracy: 0.5594 - val_loss: 0.6917 - val_accuracy: 0.8000
# Epoch 2/15
# 1/1 [==============================] - 15s 15s/step - loss: 1.1126 - accuracy: 0.7257 - val_loss: 0.4229 - val_accuracy: 0.8000
# Epoch 3/15
# 1/1 [==============================] - 27s 27s/step - loss: 0.8783 - accuracy: 0.6911 - val_loss: 0.4137 - val_accuracy: 1.0000
# Epoch 4/15
# 1/1 [==============================] - 16s 16s/step - loss: 0.8261 - accuracy: 0.5896 - val_loss: 0.5237 - val_accuracy: 0.7500
# Epoch 5/15
# 1/1 [==============================] - 16s 16s/step - loss: 0.8346 - accuracy: 0.5918 - val_loss: 0.3601 - val_accuracy: 0.9500
# Epoch 6/15
# 1/1 [==============================] - 16s 16s/step - loss: 0.7381 - accuracy: 0.6328 - val_loss: 0.2687 - val_accuracy: 0.9000
# Epoch 7/15
# 1/1 [==============================] - 16s 16s/step - loss: 0.5898 - accuracy: 0.7235 - val_loss: 0.2793 - val_accuracy: 0.8000
# Epoch 8/15
# 1/1 [==============================] - 15s 15s/step - loss: 0.5746 - accuracy: 0.7387 - val_loss: 0.2695 - val_accuracy: 0.8500
# Epoch 9/15
# 1/1 [==============================] - 15s 15s/step - loss: 0.6158 - accuracy: 0.7646 - val_loss: 0.3629 - val_accuracy: 0.8000
# Epoch 10/15
# 1/1 [==============================] - 15s 15s/step - loss: 0.5709 - accuracy: 0.7624 - val_loss: 0.2606 - val_accuracy: 0.9000
# Epoch 11/15
# 1/1 [==============================] - 17s 17s/step - loss: 0.5209 - accuracy: 0.7711 - val_loss: 0.2754 - val_accuracy: 0.9000
# Epoch 12/15
# 1/1 [==============================] - 15s 15s/step - loss: 0.4692 - accuracy: 0.7905 - val_loss: 0.3343 - val_accuracy: 0.8500
# Epoch 13/15
# 1/1 [==============================] - 16s 16s/step - loss: 0.4884 - accuracy: 0.7430 - val_loss: 0.3742 - val_accuracy: 0.9000
# Epoch 14/15
# 1/1 [==============================] - 16s 16s/step - loss: 0.5232 - accuracy: 0.7322 - val_loss: 0.2592 - val_accuracy: 0.9000
# Epoch 15/15
# 1/1 [==============================] - 15s 15s/step - loss: 0.4271 - accuracy: 0.7991 - val_loss: 0.2833 - val_accuracy: 0.9500
# Training model with activation: sigmoid
# Epoch 1/15
# 1/1 [==============================] - 22s 22s/step - loss: 1.1003 - accuracy: 0.2916 - val_loss: 0.8225 - val_accuracy: 0.2000
# Epoch 2/15
# 1/1 [==============================] - 15s 15s/step - loss: 0.8538 - accuracy: 0.3672 - val_loss: 0.6256 - val_accuracy: 0.8000
# Epoch 3/15
# 1/1 [==============================] - 21s 21s/step - loss: 0.7054 - accuracy: 0.5508 - val_loss: 0.5309 - val_accuracy: 0.8000
# Epoch 4/15
# 1/1 [==============================] - 16s 16s/step - loss: 0.6421 - accuracy: 0.6587 - val_loss: 0.4918 - val_accuracy: 0.8000
# Epoch 5/15
# 1/1 [==============================] - 15s 15s/step - loss: 0.5960 - accuracy: 0.7171 - val_loss: 0.4793 - val_accuracy: 0.8000
# Epoch 6/15
# 1/1 [==============================] - 15s 15s/step - loss: 0.6275 - accuracy: 0.7106 - val_loss: 0.4931 - val_accuracy: 0.8000
# Epoch 7/15
# 1/1 [==============================] - 16s 16s/step - loss: 0.6239 - accuracy: 0.7235 - val_loss: 0.5059 - val_accuracy: 0.8000
# Epoch 8/15
# 1/1 [==============================] - 15s 15s/step - loss: 0.6395 - accuracy: 0.7214 - val_loss: 0.4986 - val_accuracy: 0.8000
# Epoch 9/15
# 1/1 [==============================] - 14s 14s/step - loss: 0.6287 - accuracy: 0.7171 - val_loss: 0.4980 - val_accuracy: 0.8000
# Epoch 10/15
# 1/1 [==============================] - 14s 14s/step - loss: 0.6145 - accuracy: 0.7257 - val_loss: 0.4824 - val_accuracy: 0.8000
# Epoch 11/15
# 1/1 [==============================] - 16s 16s/step - loss: 0.6027 - accuracy: 0.7257 - val_loss: 0.4794 - val_accuracy: 0.8000
# Epoch 12/15
# 1/1 [==============================] - 15s 15s/step - loss: 0.6090 - accuracy: 0.7171 - val_loss: 0.4848 - val_accuracy: 0.8000
# Epoch 13/15
# 1/1 [==============================] - 16s 16s/step - loss: 0.6070 - accuracy: 0.7235 - val_loss: 0.4774 - val_accuracy: 0.8000
# Epoch 14/15
# 1/1 [==============================] - 15s 15s/step - loss: 0.5992 - accuracy: 0.7127 - val_loss: 0.4811 - val_accuracy: 0.8000
# Epoch 15/15
# 1/1 [==============================] - 15s 15s/step - loss: 0.5971 - accuracy: 0.7084 - val_loss: 0.4736 - val_accuracy: 0.8000
# Training model with activation: relu
# Epoch 1/15
# 1/1 [==============================] - 20s 20s/step - loss: 1.3212 - accuracy: 0.3499 - val_loss: 0.4448 - val_accuracy: 0.8000
# Epoch 2/15
# 1/1 [==============================] - 15s 15s/step - loss: 0.7756 - accuracy: 0.5983 - val_loss: 0.5074 - val_accuracy: 0.8000
# Epoch 3/15
# 1/1 [==============================] - 16s 16s/step - loss: 0.7560 - accuracy: 0.6955 - val_loss: 0.4792 - val_accuracy: 0.8000
# Epoch 4/15
# 1/1 [==============================] - 21s 21s/step - loss: 0.7457 - accuracy: 0.7084 - val_loss: 0.4875 - val_accuracy: 0.8000
# Epoch 5/15
# 1/1 [==============================] - 18s 18s/step - loss: 0.7116 - accuracy: 0.7149 - val_loss: 0.4223 - val_accuracy: 0.8000
# Epoch 6/15
# 1/1 [==============================] - 16s 16s/step - loss: 0.6369 - accuracy: 0.7041 - val_loss: 0.4178 - val_accuracy: 0.8000
# Epoch 7/15
# 1/1 [==============================] - 15s 15s/step - loss: 0.6029 - accuracy: 0.6803 - val_loss: 0.4649 - val_accuracy: 0.8000
# Epoch 8/15
# 1/1 [==============================] - 15s 15s/step - loss: 0.5912 - accuracy: 0.6847 - val_loss: 0.4854 - val_accuracy: 0.8500
# Epoch 9/15
# 1/1 [==============================] - 16s 16s/step - loss: 0.6188 - accuracy: 0.6566 - val_loss: 0.4613 - val_accuracy: 0.8000
# Epoch 10/15
# 1/1 [==============================] - 15s 15s/step - loss: 0.5837 - accuracy: 0.6847 - val_loss: 0.4385 - val_accuracy: 0.8500
# Epoch 11/15
# 1/1 [==============================] - 15s 15s/step - loss: 0.5675 - accuracy: 0.7127 - val_loss: 0.3846 - val_accuracy: 0.8500
# Epoch 12/15
# 1/1 [==============================] - 15s 15s/step - loss: 0.5856 - accuracy: 0.7063 - val_loss: 0.3933 - val_accuracy: 0.8000
# Epoch 13/15
# 1/1 [==============================] - 15s 15s/step - loss: 0.5344 - accuracy: 0.7408 - val_loss: 0.3774 - val_accuracy: 0.8000
# Epoch 14/15
# 1/1 [==============================] - 16s 16s/step - loss: 0.5544 - accuracy: 0.7235 - val_loss: 0.4000 - val_accuracy: 0.8000
# Epoch 15/15
# 1/1 [==============================] - 16s 16s/step - loss: 0.5085 - accuracy: 0.7667 - val_loss: 0.3562 - val_accuracy: 0.8500

# %%
# # Plot the results
# plt.figure(figsize=(10, 6))
# for activation, accuracy in results.items():
#     plt.plot(accuracy, label=activation)

# plt.title('Validation Accuracy for Different Activation Functions')
# plt.xlabel('Epochs')
# plt.ylabel('Accuracy')
# plt.legend()
# plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[20], line 3
#       1 # Plot the results
#       2 plt.figure(figsize=(10, 6))
# ----> 3 for activation, accuracy in results.items():
#       4     plt.plot(accuracy, label=activation)
#       6 plt.title('Validation Accuracy for Different Activation Functions')
#
# NameError: name 'results' is not defined

# %%
# # Plot training & validation accuracy values
# plt.plot(history.history['accuracy'])
# plt.plot(history.history['val_accuracy'])
# plt.title('Model Accuracy')
# plt.xlabel('Epoch')
# plt.ylabel('Accuracy')
# plt.legend(['Train', 'Validation'], loc='upper left')
# plt.show()

# # Plot training & validation loss values
# plt.plot(history.history['loss'])
# plt.plot(history.history['val_loss'])
# plt.title('Model Loss')
# plt.xlabel('Epoch')
# plt.ylabel('Loss')
# plt.legend(['Train', 'Validation'], loc='upper left')
# plt.show()
